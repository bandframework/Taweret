# %% [markdown]
# # Bivariate BMM Test
#
# ## Author: Alexandra Semposki
#
# ### Date: 10 September 2023

# %%
import numpy as np
import matplotlib 
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator

! pip install pandoc
# ! pip install Taweret    # if using Colab, uncomment to install

# %matplotlib inline
# Out:
# Requirement already satisfied: pandoc in /Users/alexandra/anaconda3/lib/python3.11/site-packages (2.3)
# Requirement already satisfied: plumbum in /Users/alexandra/anaconda3/lib/python3.11/site-packages (from pandoc) (1.8.3)
# Requirement already satisfied: ply in /Users/alexandra/anaconda3/lib/python3.11/site-packages (from pandoc) (3.11)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import sys
sys.path.append('../../../src/Taweret/')

# %%
from Taweret.models.samba_models import *
from Taweret.mix.gaussian import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 from Taweret.models.samba_models import *
#       2 from Taweret.mix.gaussian import *
#
# ModuleNotFoundError: No module named 'Taweret.models'

# %%
g = np.linspace(1e-6, 1.0, 100)
order = 3

# %%
model_1 = Loworder(order)
model_2 = Highorder(order)
true = TrueModel().evaluate(g)

exp_1 = model_1.evaluate(g)
exp_2 = model_2.evaluate(g)

var_1 = exp_1[1].flatten()
var_2 = exp_2[1].flatten()

# combine to form dict of models
models = {
    '1': model_1,
    '2': model_2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model_1 = Loworder(order)
#       2 model_2 = Highorder(order)
#       3 true = TrueModel().evaluate(g)
#
# NameError: name 'Loworder' is not defined

# %%
#example plot to test models
fig = plt.figure(figsize=(8,6), dpi=100)
ax = plt.axes()
ax.set_xlim(0.0,1.0)
ax.set_ylim(1.2,3.2)
ax.tick_params(axis='x', direction='in')
ax.tick_params(axis='y', direction='in')
ax.locator_params(nbins=8)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

ax.plot(g, true[0].flatten(), 'k', label='True')
ax.plot(g, exp_1[0].flatten(), 'r--', label='Small-g')
ax.plot(g, exp_2[0].flatten(), 'b--', label='Large-g')

ax.set_title('SAMBA Models')
ax.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 12
#       9 ax.xaxis.set_minor_locator(AutoMinorLocator())
#      10 ax.yaxis.set_minor_locator(AutoMinorLocator())
# ---> 12 ax.plot(g, true[0].flatten(), 'k', label='True')
#      13 ax.plot(g, exp_1[0].flatten(), 'r--', label='Small-g')
#      14 ax.plot(g, exp_2[0].flatten(), 'b--', label='Large-g')
#
# NameError: name 'true' is not defined

# %%
#call mixing method and plot
mixed = Multivariate(g, models, n_models=2)
_, mixed_mean, mixed_intervals, mixed_std_dev = mixed.predict(ci=68)

# %%
#plotting bivariate BMM results on top of SAMBA models
fig = plt.figure(figsize=(8,6), dpi=100)
ax = plt.axes()
ax.set_xlim(0.0,1.0)
ax.set_ylim(1.0,3.0)
ax.tick_params(axis='x', direction='in')
ax.tick_params(axis='y', direction='in')
ax.locator_params(nbins=8)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())

ax.plot(g, true[0].flatten(), 'k', label='True')
ax.plot(g, exp_1[0].flatten(), 'r--', label='Small-g')
ax.plot(g, exp_2[0].flatten(), 'b--', label='Large-g')

ax.plot(g, exp_1[0].flatten() - var_1, 'r', linestyle='dotted')
ax.plot(g, exp_1[0].flatten() + var_1, 'r', linestyle='dotted')

ax.plot(g, exp_2[0].flatten() - var_2, 'b', linestyle='dotted')
ax.plot(g, exp_2[0].flatten() + var_2, 'b', linestyle='dotted')

ax.plot(g, mixed_mean, 'g', label='Mixed model')
ax.plot(g, mixed_intervals[0][0], 'g--')
ax.plot(g, mixed_intervals[1][0], 'g--')
ax.fill_between(g, mixed_intervals[0][0], mixed_intervals[1][0], color='green', alpha=0.2)

ax.set_title('SAMBA Models')
ax.legend()

# %% [markdown]
# Written by: Alexandra Semposki
#
# Last edited: 10 September 2023
